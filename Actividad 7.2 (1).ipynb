# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.read_csv('datasets/antropometria-dataset.csv')
                 
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
df.shape
# Out:
# (18640, 26)

# %%
plt.hist([df["sistol"],df["diastol"]], label=["diastol","sistol"])
plt.legend(loc="center right")

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
plt.hist([df["peso"],df["cintura"]], label=["cintura","peso"])
plt.legend(loc="center right")

# %%
a = df['peso']
b = df['cintura']

# %%
plt.scatter(a,b,
           c='r',
           label = 'Puntos',)
plt.xlabel('peso')
plt.ylabel('cintura')
plt.legend()
plt.show()

# %%
#¿Cómo son cada una de las distribuciones (simétrica, asimétrica, sesgada a la izquierda, segada a la derecha)?
#Son simetricas pero considero que se encuentran un poco sesgadas a ambos lados pero mas que nada hacia la izquiera
#podemos observar un mayor sesgo.

# %%
#Al visualizar los histogramas ¿existen valores atípicos?
#Si ya que en la relacion de cintura y peso podemos ver una barra del peso muy alejada de las demas.

# %%
#¿Cómo es el comportamiento del peso con respecto a la cintura?
#Considero que se mantiene constante ya que al incremento del peso de igual manera hay un crecimiento constante de la cintura,
#con algunas excepciones en las que es disparejo el tamaño de la cintura con el del peso.(los valores atipicos.)

# %%
#Al visualizar el diagrama de dispersión entre la variables 'peso' y 'cintura' ¿existen valores atípicos?
#Se observan valores atipicos en la parte superior de nuestro diagrama por lo que si existen.
